# %% [markdown]
# # Beautiful Soup
#
# **Beautiful Soup** is a Python library for parsing HTML and XML documents, enabling easy navigation, searching, and modification of web page content in a structured way.

# %%
# !pip install beautifulsoup4 requests

# %%
import requests
from bs4 import BeautifulSoup

# Fetch a webpage
url = "https://www.sanlam.com/governance.php"
response = requests.get(url)

# Parse the HTML
soup = BeautifulSoup(response.text, "html.parser")

# Pretty print the HTML structure
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Investor Centre | Governance | Sanlam
#   </title>
#   <meta charset="utf-8">
#    <!-- prevent skype styles on telephone numbers -->
#    <meta content="telephone=no" name="format-detection"/>
#    <meta content="SKYPE_TOOLBAR_PARSER_COMPATIBLE" name="SKYPE_TOOLBAR">
#     <meta content="yes" name="apple-mobile-web-app-capable"/>
#     <link href="images/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#     <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
#     <meta content="Sanlam" name="author"/>
#     <meta content="index, follow" name="robots"/>
#     <link href="https://use.typekit.net/npe3dbj.css" rel="stylesheet"/>
#     <link href="css/normalize.css" rel="stylesheet">
#      <link href="css/font-awesome.min.css" rel="stylesheet"/>
#      <link href="css/fonts.css" rel="stylesheet"/>
#      <link href="css/global.css" rel="stylesheet"/>
# ...
